# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.16.2-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.1 MB 1.3 MB/s eta 0:00:01
#      --- ------------------------------------ 0.1/1.1 MB 1.3 MB/s eta 0:00:01
#      --------- ------------------------------ 0.3/1.1 MB 2.1 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.5/1.1 MB 2.9 MB/s eta 0:00:01
#      -------------------------- ------------- 0.7/1.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.0/1.1 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\wicm\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: numpy in c:\users\wicm\anaconda3\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in c:\users\wicm\anaconda3\lib\site-packages (from torchvision) (2.30.0)
# Collecting torch==2.1.2
#   Downloading torch-2.1.2-cp39-cp39-win_amd64.whl (192.2 MB)
#      ---------------------------------------- 0.0/192.2 MB ? eta -:--:--
#      --------------------------------------- 0.8/192.2 MB 16.8 MB/s eta 0:00:12
#      --------------------------------------- 1.4/192.2 MB 14.9 MB/s eta 0:00:13
#      --------------------------------------- 2.0/192.2 MB 14.3 MB/s eta 0:00:14
#       -------------------------------------- 2.7/192.2 MB 15.7 MB/s eta 0:00:13
#       -------------------------------------- 3.3/192.2 MB 14.0 MB/s eta 0:00:14
#       -------------------------------------- 4.1/192.2 MB 14.4 MB/s eta 0:00:14
#       -------------------------------------- 4.8/192.2 MB 15.2 MB/s eta 0:00:13
#      - ------------------------------------- 5.5/192.2 MB 15.2 MB/s eta 0:00:13
#      - ------------------------------------- 6.2/192.2 MB 15.3 MB/s eta 0:00:13
#      - ------------------------------------- 6.9/192.2 MB 15.2 MB/s eta 0:00:13
#      - ------------------------------------- 7.8/192.2 MB 15.6 MB/s eta 0:00:12
#      - ------------------------------------- 8.2/192.2 MB 15.4 MB/s eta 0:00:12
#      - ------------------------------------- 8.9/192.2 MB 14.9 MB/s eta 0:00:13
#      - ------------------------------------- 9.4/192.2 MB 14.7 MB/s eta 0:00:13
#      -- ----------------------------------- 10.2/192.2 MB 14.9 MB/s eta 0:00:13
#      -- ----------------------------------- 10.8/192.2 MB 14.2 MB/s eta 0:00:13
#      -- ----------------------------------- 11.9/192.2 MB 14.9 MB/s eta 0:00:13
#      -- ----------------------------------- 12.9/192.2 MB 15.6 MB/s eta 0:00:12
#      -- ----------------------------------- 13.8/192.2 MB 16.4 MB/s eta 0:00:11
#      -- ----------------------------------- 14.7/192.2 MB 16.8 MB/s eta 0:00:11
#      --- ---------------------------------- 15.8/192.2 MB 17.7 MB/s eta 0:00:10
#      --- ---------------------------------- 16.0/192.2 MB 16.4 MB/s eta 0:00:11
#      --- ---------------------------------- 17.6/192.2 MB 16.8 MB/s eta 0:00:11
#      --- ---------------------------------- 17.9/192.2 MB 16.0 MB/s eta 0:00:11
#      --- ---------------------------------- 19.3/192.2 MB 17.7 MB/s eta 0:00:10
#      --- ---------------------------------- 19.9/192.2 MB 17.2 MB/s eta 0:00:11
#      ---- --------------------------------- 21.0/192.2 MB 18.7 MB/s eta 0:00:10
#      ---- --------------------------------- 22.1/192.2 MB 18.2 MB/s eta 0:00:10
#      ---- --------------------------------- 22.9/192.2 MB 18.2 MB/s eta 0:00:10
 4.5 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (2023.4.0)
# Requirement already satisfied: sympy in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (1.11.1)
# Requirement already satisfied: typing-extensions in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (4.5.0)
# Requirement already satisfied: filelock in c:\users\wicm\anaconda3\lib\site-packages (from torch==2.1.2->torchvision) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wicm\anaconda3\lib\site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wicm\anaconda3\lib\site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wicm\anaconda3\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wicm\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wicm\anaconda3\lib\site-packages (from jinja2->torch==2.1.2->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\wicm\anaconda3\lib\site-packages (from sympy->torch==2.1.2->torchvision) (1.2.1)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed torch-2.1.2 torchvision-0.16.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from torchvision.io import read_video,read_video_timestamps
from torch.utils.data import Dataset
from torchvision.datasets import VisionDataset

import matplotlib.pyplot as plt
import torchvision.transforms.functional as F
import numpy as np

# %%
class CustomVidDataset(VisionDataset):
    def __init__(self, annotations_file, vid_dir, transform= None, target_transform=None):
        self.vid_labels = pd.read_csv(annotations_file)
        self.vid_dir = vid_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.vid_labels)

    def __getitem__(self, idx):

        vid_path = os.path.join(self.vid_dir, self.vid_labels.iloc[idx, 0])
        vid,_,_ = read_video(vid_path,pts_unit='sec',end_pts=10.0)
        label = self.vid_labels.iloc[idx, 5:17]
        array_label = label.to_numpy()
        array_label = array_label.astype(int)
        trans_vid = vid[:5] # slice only first 5 frames
        if self.transform:
            trans_vid = self.transform(trans_vid)
        if self.target_transform:
            label = self.target_transform(array_label)
        return trans_vid, array_label

# %%
if __name__ == "__main__":
    from torchvision.models.video import MViT_V1_B_Weights

    transforms = MViT_V1_B_Weights.KINETICS400_V1.transforms()
    data_vid_load = CustomVidDataset(annotations_file = 'dataset_label_adjusted.csv',vid_dir = r'C:\Users\wicm\dads7002_final\dads-7202-final-project\data',transform=transforms)


    x,y = data_vid_load.__getitem__(1)

    print(x.shape)
    print('dd')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 from torchvision.models.video import MViT_V1_B_Weights
#       4 transforms = MViT_V1_B_Weights.KINETICS400_V1.transforms()
# ----> 5 data_vid_load = CustomVidDataset(annotations_file = 'dataset_label_adjusted.csv',vid_dir = r'C:\Users\wicm\dads7002_final\dads-7202-final-project\data',transform=transforms)
#       8 x,y = data_vid_load.__getitem__(1)
#      10 print(x.shape)
#
# Cell In[7], line 3, in CustomVidDataset.__init__(self, annotations_file, vid_dir, transform, target_transform)
#       2 def __init__(self, annotations_file, vid_dir, transform= None, target_transform=None):
# ----> 3     self.vid_labels = pd.read_csv(annotations_file)
#       4     self.vid_dir = vid_dir
#       5     self.transform = transform
#
# File c:\Users\wicm\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\wicm\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\wicm\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\wicm\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\wicm\Anaconda3\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset_label_adjusted.csv'
